# %%
def read_lines(path):
    return [line.strip() for line in open(path, 'r')]

# %%
import glob

paths = glob.glob('*.txt')
files = {}

for p in paths:
    files[p] = read_lines(p)

files
# Out:
# {'requirements.txt': ['ipython', 'numpy', 'matplotlib'],
#  'squares.txt': ['0^2 = 0',
#   '1^2 = 1',
#   '2^2 = 4',
#   '3^2 = 9',
#   '4^2 = 16',
#   '5^2 = 25',
#   '6^2 = 36',
#   '7^2 = 49',
#   '8^2 = 64',
#   '9^2 = 81'],
#  'cubes.txt': ['0^3 = 0',
#   '1^3 = 1',
#   '2^3 = 8',
#   '3^3 = 27',
#   '4^3 = 64',
#   '5^3 = 125',
#   '6^3 = 216',
#   '7^3 = 343',
#   '8^3 = 512',
#   '9^3 = 729',
#   '10^3 = 1000',
#   '11^3 = 1331',
#   '12^3 = 1728',
#   '13^3 = 2197',
#   '14^3 = 2744',
#   '15^3 = 3375',
#   '16^3 = 4096',
#   '17^3 = 4913',
#   '18^3 = 5832',
#   '19^3 = 6859',
#   '20^3 = 8000',
#   '21^3 = 9261',
#   '22^3 = 10648',
#   '23^3 = 12167',
#   '24^3 = 13824',
#   '25^3 = 15625',
#   '26^3 = 17576',
#   '27^3 = 19683',
#   '28^3 = 21952',
#   '29^3 = 24389',
#   '30^3 = 27000',
#   '31^3 = 29791',
#   '32^3 = 32768',
#   '33^3 = 35937',
#   '34^3 = 39304',
#   '35^3 = 42875',
#   '36^3 = 46656',
#   '37^3 = 50653',
#   '38^3 = 54872',
#   '39^3 = 59319',
# ...
